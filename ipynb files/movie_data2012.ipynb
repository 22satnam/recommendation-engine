# %%
import pandas as pd
import numpy as np

# %%
link = 'https://en.wikipedia.org/wiki/List_of_Bollywood_films_of_2012'
df1 = pd.read_html(link, header=0)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df = df1.append(df2.append(df3.append(df4, ignore_index=True), ignore_index=True), ignore_index=True)

# %%
df
# Out:
#    Rank  ...           Genre
# 0     1  ...             NaN
# 1     2  ...             NaN
# 2     3  ...             NaN
# 3     4  ...             NaN
# 4     5  ...             NaN
# ..  ...  ...             ...
# 87  NaN  ...  Romance/Comedy
# 88  NaN  ...           Drama
# 89  NaN  ...     Adult/Drama
# 90  NaN  ...          Comedy
# 91  NaN  ...  Comedy/Fantasy
#
# [92 rows x 10 columns]

# %%
dfb_2013 = df[['Title', 'Director', 'Cast', 'Genre']]

# %%
dfb_2013[['Actor1','Actor2','Actor3','Actor4', 'Actor5', 'Actor6', 'Actor7', 'Actor8', 'Actor9', 'Actor10', 'Actor11', 'Actor12']] = dfb_2013.Cast.apply(lambda x : pd.Series(str(x).split(", ")))
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:3069: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
dfb_2013
# Out:
#                       Title           Director  ... Actor11 Actor12
# 0                       NaN                NaN  ...     NaN     NaN
# 1                       NaN                NaN  ...     NaN     NaN
# 2                       NaN                NaN  ...     NaN     NaN
# 3                       NaN                NaN  ...     NaN     NaN
# 4                       NaN                NaN  ...     NaN     NaN
# ..                      ...                ...  ...     ...     ...
# 87                   Barfi!        Anurag Basu  ...     NaN     NaN
# 88  Jeena Hai Toh Thok Daal    Manish Vatsalya  ...     NaN     NaN
# 89                  Heroine  Madhur Bhandarkar  ...     NaN     NaN
# 90  Kamaal Dhamaal Malamaal       Priyadarshan  ...     NaN     NaN
# 91         OMG – Oh My God!       Umesh Shukla  ...     NaN     NaN
#
# [92 rows x 16 columns]

# %%
for i in range(4, 13):
  x = 'Actor'
  dfb_2013.drop(x+str(i),axis=1,inplace=True)

# %%
dfb_2013
# Out:
#                       Title  ...              Actor3
# 0                       NaN  ...                 NaN
# 1                       NaN  ...                 NaN
# 2                       NaN  ...                 NaN
# 3                       NaN  ...                 NaN
# 4                       NaN  ...                 NaN
# ..                      ...  ...                 ...
# 87                   Barfi!  ...   Ileana D'Cruz[63]
# 88  Jeena Hai Toh Thok Daal  ...       Govind Namdev
# 89                  Heroine  ...       Randeep Hooda
# 90  Kamaal Dhamaal Malamaal  ...        Nana Patekar
# 91         OMG – Oh My God!  ...  Mithun Chakraborty
#
# [92 rows x 7 columns]

# %%
dfb_2013 = dfb_2013.rename(columns={'Title':'movie_title', 'Director':'director_name','Actor1':'actor_1_name','Actor2':'actor_2_name','Actor3':'actor_3_name','Cast':'comb','Genre':'genres'})

# %%
dfb_2013
# Out:
#                 movie_title  ...        actor_3_name
# 0                       NaN  ...                 NaN
# 1                       NaN  ...                 NaN
# 2                       NaN  ...                 NaN
# 3                       NaN  ...                 NaN
# 4                       NaN  ...                 NaN
# ..                      ...  ...                 ...
# 87                   Barfi!  ...   Ileana D'Cruz[63]
# 88  Jeena Hai Toh Thok Daal  ...       Govind Namdev
# 89                  Heroine  ...       Randeep Hooda
# 90  Kamaal Dhamaal Malamaal  ...        Nana Patekar
# 91         OMG – Oh My God!  ...  Mithun Chakraborty
#
# [92 rows x 7 columns]

# %%
new_dfb13 = dfb_2013.loc[:,['director_name','actor_1_name','actor_2_name','actor_3_name','genres','movie_title']]

# %%
new_dfb13
# Out:
#         director_name    actor_1_name  ...          genres              movie_title
# 0                 NaN             nan  ...             NaN                      NaN
# 1                 NaN             nan  ...             NaN                      NaN
# 2                 NaN             nan  ...             NaN                      NaN
# 3                 NaN             nan  ...             NaN                      NaN
# 4                 NaN             nan  ...             NaN                      NaN
# ..                ...             ...  ...             ...                      ...
# 87        Anurag Basu   Ranbir Kapoor  ...  Romance/Comedy                   Barfi!
# 88    Manish Vatsalya     Ravi Kishan  ...           Drama  Jeena Hai Toh Thok Daal
# 89  Madhur Bhandarkar  Kareena Kapoor  ...     Adult/Drama                  Heroine
# 90       Priyadarshan    Paresh Rawal  ...          Comedy  Kamaal Dhamaal Malamaal
# 91       Umesh Shukla    Paresh Rawal  ...  Comedy/Fantasy         OMG – Oh My God!
#
# [92 rows x 6 columns]

# %%
new_dfb13['actor_2_name'] = new_dfb13['actor_2_name'].replace(np.nan, 'unknown')
new_dfb13['actor_3_name'] = new_dfb13['actor_3_name'].replace(np.nan, 'unknown')

# %%
new_dfb13['movie_title'] = new_dfb13['movie_title'].str.lower()

# %%
new_dfb13['comb'] = new_dfb13['actor_1_name'] + ' ' + new_dfb13['actor_2_name'] + ' '+ new_dfb13['actor_3_name'] + ' '+ new_dfb13['director_name'] +' ' + new_dfb13['genres']

# %%
new_dfb13
# Out:
#         director_name  ...                                               comb
# 0                 NaN  ...                                                NaN
# 1                 NaN  ...                                                NaN
# 2                 NaN  ...                                                NaN
# 3                 NaN  ...                                                NaN
# 4                 NaN  ...                                                NaN
# ..                ...  ...                                                ...
# 87        Anurag Basu  ...  Ranbir Kapoor Priyanka Chopra Ileana D'Cruz[63...
# 88    Manish Vatsalya  ...  Ravi Kishan Yashpal Sharma Govind Namdev Manis...
# 89  Madhur Bhandarkar  ...  Kareena Kapoor Arjun Rampal Randeep Hooda Madh...
# 90       Priyadarshan  ...  Paresh Rawal Om Puri Nana Patekar Priyadarshan...
# 91       Umesh Shukla  ...  Paresh Rawal Akshay Kumar Mithun Chakraborty U...
#
# [92 rows x 7 columns]

# %%
old_df = pd.read_csv('2011.csv')

# %%
old_df
# Out:
#       director_name  ...                                               comb
# 0    Muddassar Aziz  ...  Fardeen Khan Ishita Sharma Sushmita Sen Muddas...
# 1     Jugal Hansraj  ...  Priyanka Chopra Uday Chopra Anupam Kher Jugal ...
# 2         Ken Ghosh  ...  Shahid Kapoor Genelia D'Souza unknown Ken Ghos...
# 3     Dileep Shukla  ...  Rajpal Yadav Preeti Mehra unknown Dileep Shukl...
# 4       Anil Sharma  ...  Salman Khan Zarine Khan Mithun Chakraborty Ani...
# ..              ...  ...                                                ...
# 183   Milan Luthria  ...  Vidya Balan Naseeruddin Shah Tusshar Kapoor Mi...
# 184  Maneesh Sharma  ...  Ranveer Singh Anushka Sharma Parineeti Chopra ...
# 185      Pawan Gill  ...  Sunny Gill Simran Kaur Mundi Achint Kaur Pawan...
# 186  Saurabh Shukla  ...  Vinay Pathak Neha Dhupia Rajat Kapoor Saurabh ...
# 187   Farhan Akhtar  ...  Shahrukh Khan Priyanka Chopra Lara Dutta Farha...
#
# [188 rows x 7 columns]

# %%
final_df = old_df.append(new_dfb13,ignore_index=True)

# %%
final_df
# Out:
#          director_name  ...                                               comb
# 0       Muddassar Aziz  ...  Fardeen Khan Ishita Sharma Sushmita Sen Muddas...
# 1        Jugal Hansraj  ...  Priyanka Chopra Uday Chopra Anupam Kher Jugal ...
# 2            Ken Ghosh  ...  Shahid Kapoor Genelia D'Souza unknown Ken Ghos...
# 3        Dileep Shukla  ...  Rajpal Yadav Preeti Mehra unknown Dileep Shukl...
# 4          Anil Sharma  ...  Salman Khan Zarine Khan Mithun Chakraborty Ani...
# ..                 ...  ...                                                ...
# 275        Anurag Basu  ...  Ranbir Kapoor Priyanka Chopra Ileana D'Cruz[63...
# 276    Manish Vatsalya  ...  Ravi Kishan Yashpal Sharma Govind Namdev Manis...
# 277  Madhur Bhandarkar  ...  Kareena Kapoor Arjun Rampal Randeep Hooda Madh...
# 278       Priyadarshan  ...  Paresh Rawal Om Puri Nana Patekar Priyadarshan...
# 279       Umesh Shukla  ...  Paresh Rawal Akshay Kumar Mithun Chakraborty U...
#
# [280 rows x 7 columns]

# %%
final_df.isna().sum()
# Out:
# director_name    11
# actor_1_name      1
# actor_2_name      0
# actor_3_name      0
# genres           11
# movie_title      11
# comb             11
# dtype: int64

# %%
final_df = final_df.dropna(how='any')

# %%
final_df.isna().sum()
# Out:
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# genres           0
# movie_title      0
# comb             0
# dtype: int64

# %%
final_df.to_csv('2012.csv',index=False)
